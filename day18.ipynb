# %%
# !python3 -m pip install SpeechRecognition
# !python3 -m pip install nltk
# !python3 -m pip install pyttsx3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SpeechRecognition in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (3.10.0)
# Requirement already satisfied: requests>=2.26.0 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (2023.7.22)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from nltk) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from nltk) (4.65.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyttsx3 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (2.90)
# Requirement already satisfied: pyobjc>=2.4 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-core==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AddressBook==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Automator==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CFNetwork==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Cocoa==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreAudio==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreData==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreText==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-DiscRecording==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-LaunchServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-OSAKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Quartz==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Security==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SearchKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SyncServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-WebKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreLocation==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-IOSurface==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-NetFS==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AVFoundation==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreMedia==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-StoreKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SceneKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-libdispatch==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-libxpc==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Accounts==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-EventKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-GameCenter==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Social==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-GameKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AVKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-GameController==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MapKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SpriteKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CloudKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-FinderSync==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Contacts==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ContactsUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Metal==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MetalKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ModelIO==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Photos==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-PhotosUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-GameplayKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Intents==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SafariServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ColorSync==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreML==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Vision==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AdSupport==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-BusinessChat==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Network==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-UserNotifications==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CoreMotion==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-FileProvider==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-OSLog==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-PencilKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-PushKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Speech==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Accessibility==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AdServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CallKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ClassKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-KernelManagement==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MLCompute==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-PassKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ReplayKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ScreenTime==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Virtualization==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-DataDetection==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-IntentsUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MailKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MetricKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-PHASE==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ShazamKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-AVRouting==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-HealthKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-MetalFX==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SafetyKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-CalendarStore==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-Collaboration==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-FSEvents==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-InstantMessage==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==9.2 in /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages (from pyobjc>=2.4->pyttsx3) (9.2)

# %%
import speech_recognition as sr
import nltk
import pyttsx3

# pyaudio wheel file
# Out:
# /Users/sanampeeyush/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import cv2
from time import sleep
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
vid = cv2.VideoCapture(index = 0)
while True:
    ack, img = vid.read()
    if ack:
        people, weights = hog.detectMultiScale(
            cv2.cvtColor(img, cv2.COLOR_BGR2GRAY), winStride = (15,15),
        )
        for x,y,w,h in people:
            cv2.rectangle(
                img, pt1=(x,y), pt2=(x+w,y+h), color=(0,0,255), thickness=5,
            )
        sleep(0.1)
        cv2.imshow('Preview',img)
        if cv2.waitKey(delay = 1) == ord('q'):
            break
cv2.destroyAllWindows(); cv2.waitKey(1)
vid.release()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       6 ack, img = vid.read()
#       7 if ack:
# ----> 8     people, weights = hog.detectMultiScale(
#       9         cv2.cvtColor(img, cv2.COLOR_BGR2GRAY), winStride = (15,15),
#      10     )
#      11     for x,y,w,h in people:
#      12         cv2.rectangle(
#      13             img, pt1=(x,y), pt2=(x+w,y+h), color=(0,0,255), thickness=5,
#      14         )
#
# KeyboardInterrupt:

# %%
# Rule Based Chatbot

# %%
import pyttsx3
tts = pyttsx3.init()
tts.setProperty('rate',100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 tts = pyttsx3.init()
#       3 tts.setProperty('rate',100)
# ----> 4 tts.startLoop()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyttsx3/engine.py:196, in Engine.startLoop(self, useDriverLoop)
#     194 self._inLoop = True
#     195 self._driverLoop = useDriverLoop
# --> 196 self.proxy.startLoop(self._driverLoop)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyttsx3/driver.py:199, in DriverProxy.startLoop(self, useDriverLoop)
#     195 '''
#     196 Called by the engine to start an event loop.
#     197 '''
#     198 if useDriverLoop:
# --> 199     self._driver.startLoop()
#     200 else:
#     201     self._iterator = self._driver.iterate()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyttsx3/drivers/nsss.py:35, in NSSpeechDriver.startLoop(self)
#      32 def startLoop(self):
#      33     NSTimer.scheduledTimerWithTimeInterval_target_selector_userInfo_repeats_(
#      34         0.0, self, 'onPumpFirst:', None, False)
# ---> 35     AppHelper.runConsoleEventLoop()
#
# File ~/Library/Python/3.9/lib/python/site-packages/PyObjCTools/AppHelper.py:262, in runConsoleEventLoop(argv, installInterrupt, mode, maxTimeout)
#     260         if nextfire is not None:
#     261             nextfire = soon.earlierDate_(nextfire)
# --> 262         if not runLoop.runMode_beforeDate_(mode, nextfire):
#     263             stopper.stop()
#     265 finally:
#
# KeyboardInterrupt:

# %%
tts.say('Hello! I am speaking for you from your computer')
# tts.runAndWait()
# tts.stop()

# %%
import warnings; warnings.filterwarnings('ignore')
import speech_recognition as sr
import webbrowser as web
rec = sr.Recognizer()
flag = False
while True:
    with sr.Microphone() as mic:
        print('Speak:')
        audio = rec.listen(mic,phrase_time_limit=3,timeout=5)
        try:
            text = rec.recognize_google(audio).lower()
            print(text)
            if flag == True:
                if 'search' in text:
                    item = text.split('search')[-1].strip()
                    flipkart_url = 'https://flipkart.com/search?q='
                    amazon_url = 'https://amazon.in/s?k='
                    web.open_new(flipkart_url + item)
                    web.open_new_tab(amazon_url + item)                    
                flag = False

            if 'hey google' in text:
                flag = True
            elif 'mar ja' in text: 
                break

            # if flag == False:
            #     print('You said:',text)
            # tts.say(text)
            # tts.runAndWait()
        except Exception as err:
            print(err)
# Out:
# Speak:
# Speak:
# Speak:
#
# Speak:
#
# Speak:
# Speak:

# %%
from nltk.chat.util import Chat

# %%
q1 = r'(.*)your name (.*)company(.*)'
a1 = ['my name is chatchat','I am chatchat']
q2 = r'kya aaj kuch achha hoga'
a2 = ['haan','mujhe kya pata','mein kyo batau']
qa_pair = [
    [q1,a1],
    [q2,a2],
]
cb = Chat(qa_pair)

# %%
ques = input('enter ques:').lower()
resp = cb.respond(ques)
print(resp)
# Out:
# I am chatchat

# %%
# Regular Expressions
#######################
# ()      Capture & Group
# .       Any character (except new line)
# *       zero or more occurrences
# |       or
# []      set of characters
# a-z
# A-Z
# 0-9
# ^       starting with
# $       ends with
# ?       zero or one occurrence
# +       one or more occurrence
# {}      exact number of occurrence
# \w      only word characters
# \W      not word characters

# %%
from nltk.chat.util import Chat
import speech_recognition as sr
import pyttsx3

q1 = r'(.*)your name (.*)company(.*)'
a1 = ['my name is chatchat','I am chatchat']
q2 = r'kya aaj kuch achha hoga'
a2 = ['haan','mujhe kya pata','mein kyo batau']
qa_pair = [
    [q1,a1],
    [q2,a2],
]
cb = Chat(qa_pair)
tts = pyttsx3.init()
rec = sr.Recognizer()
while True:
    with sr.Microphone() as mic:
        print('Speak:')
        audio = rec.listen(mic,phrase_time_limit=3,timeout=5)
        try:
            text = rec.recognize_google(audio).lower()
            print(text)
            if flag == True:
                if 'search' in text:
                    item = text.split('search')[-1].strip()
                    flipkart_url = 'https://flipkart.com/search?q='
                    amazon_url = 'https://amazon.in/s?k='
                    web.open_new(flipkart_url + item)
                    web.open_new_tab(amazon_url + item)
                else:
                    resp = cb.respond(text)
                    if resp == None:
                        tts.say('Sorry, I dont know')
                    else:
                        tts.say(resp)
                    tts.runAndWait()
                flag = False
            if 'hey google' in text:
                flag = True
            elif 'mar ja' in text: 
                break
        except Exception as err:
            print(err)
